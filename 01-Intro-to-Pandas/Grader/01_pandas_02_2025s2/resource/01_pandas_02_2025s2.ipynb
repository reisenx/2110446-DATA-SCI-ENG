# %% [markdown]
# # Unit 01: Intro to Pandas (`01_pandas_02_2025s2`)

# %% [markdown]
# # Dependencies

# %%
import os
import pandas as pd

# %% [markdown]
# # Data Resources
# Directory & File Path

# %%
# This folder directory path.
CODE_DIRECTORY = os.getcwd()

# The resources file paths.
VIDEOS_FILE = os.path.normpath(os.path.join(CODE_DIRECTORY, "..", "code", "videos.csv"))
CATEGORIES_FILE = os.path.normpath(
    os.path.join(CODE_DIRECTORY, "..", "code", "category_id.json")
)

# %% [markdown]
# Load Files

# %%
# The original video DataFrame for Q1.
INITIAL_VIDEO_DF = pd.read_csv(VIDEOS_FILE)

# The video DataFrame that has duplicates removed for Q2 - Q5.
VIDEO_DF = INITIAL_VIDEO_DF.drop_duplicates()

# The video categories from a JSON file.
CATEGORIES_DF = pd.read_json(CATEGORIES_FILE)

# %% [markdown]
# Display video DataFrame

# %%
VIDEO_DF.head(10)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
# 6  39idVpFF7NQ      17.14.11
# 7  nc99ccSXST0      17.14.11
# 8  jr9QtXwC9vc      17.14.11
# 9  TUmyygCMMGA      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
# 6          Roy Moore & Jeff Sessions Cold Open - SNL    Saturday Night Live
# 7                5 Ice Cream Gadgets put to the Test     CrazyRussianHacker
# 8  The Greatest Showman | Official Trailer 2 [HD]...       20th Century Fox
# 9  Why the rise of the robots won’t mean the end ...                    Vox
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
# 5           28  2017-11-13T19:07:23.000Z
# 6           24  2017-11-12T05:37:17.000Z
# 7           28  2017-11-12T21:50:37.000Z
# 8            1  2017-11-13T14:00:23.000Z
# 9           25  2017-11-13T13:45:16.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
# 5  ijustine|"week with iPhone X"|"iphone x"|"appl...   119180    9763
# 6  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...  2103417   15993
# 7  5 Ice Cream Gadgets|"Ice Cream"|"Cream Sandwic...   817732   23663
# 8  Trailer|"Hugh Jackman"|"Michelle Williams"|"Za...   826059    3543
# 9  vox.com|"vox"|"explain"|"shift change"|"future...   256426   12654
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
# 5       511           1434  https://i.ytimg.com/vi/gHZ1Qz0KiKM/default.jpg
# 6      2445           1970  https://i.ytimg.com/vi/39idVpFF7NQ/default.jpg
# 7       778           3432  https://i.ytimg.com/vi/nc99ccSXST0/default.jpg
# 8       119            340  https://i.ytimg.com/vi/jr9QtXwC9vc/default.jpg
# 9      1363           2368  https://i.ytimg.com/vi/TUmyygCMMGA/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
# 5              False             False                   False
# 6              False             False                   False
# 7              False             False                   False
# 8              False             False                   False
# 9              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...
# 5  Using the iPhone for the past two weeks -- her...
# 6  Embattled Alabama Senate candidate Roy Moore (...
# 7  Ice Cream Pint Combination Lock - http://amzn....
# 8  Inspired by the imagination of P.T. Barnum, Th...
# 9  For now, at least, we have better things to wo...

# %% [markdown]
# Display categories DataFrame

# %%
CATEGORIES_DF.head(10)
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
# 5  youtube#videoCategoryListResponse
# 6  youtube#videoCategoryListResponse
# 7  youtube#videoCategoryListResponse
# 8  youtube#videoCategoryListResponse
# 9  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 5  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 6  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 7  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 8  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 9  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 5  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 6  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 7  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 8  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 9  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %% [markdown]
# # Function `Q1`
# How many rows are there in the videos.csv after removing duplications on video DataFrame?

# %% [markdown]
# ## Duplicate Rows
# Example of duplicates row in the initial video DataFrame.

# %%
INITIAL_VIDEO_DF[INITIAL_VIDEO_DF.duplicated(keep=False)].sort_values(
    by="video_id"
).head(10)
# Out:
#           video_id trending_date  \
# 34906  1RZYOeQeIXE      18.15.05
# 34757  1RZYOeQeIXE      18.15.05
# 34917  1U1u5aKU3AY      18.15.05
# 34768  1U1u5aKU3AY      18.15.05
# 34799  2PH7dK6SLC8      18.15.05
# 34948  2PH7dK6SLC8      18.15.05
# 34919  3g5O-kT9m8k      18.15.05
# 34770  3g5O-kT9m8k      18.15.05
# 34913  4oqvNR1o3Zo      18.15.05
# 34764  4oqvNR1o3Zo      18.15.05
#
#                                                    title       channel_title  \
# 34906   Sarah Paulson Gets Scared During '5 Second Rule'        TheEllenShow
# 34757   Sarah Paulson Gets Scared During '5 Second Rule'        TheEllenShow
# 34917  New lava fissures fuel fears of eruption in Ha...                 CNN
# 34768  New lava fissures fuel fears of eruption in Ha...                 CNN
# 34799                             John Mayer - New Light       johnmayerVEVO
# 34948                             John Mayer - New Light       johnmayerVEVO
# 34919                       $1000 Survival Kit in a Case  CrazyRussianHacker
# 34770                       $1000 Survival Kit in a Case  CrazyRussianHacker
# 34913  24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 Diggi...           Papa Jake
# 34764  24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 Diggi...           Papa Jake
#
#        category_id              publish_time  \
# 34906           24  2018-05-14T13:00:00.000Z
# 34757           24  2018-05-14T13:00:00.000Z
# 34917           25  2018-05-13T19:30:53.000Z
# 34768           25  2018-05-13T19:30:53.000Z
# 34799           10  2018-05-10T17:00:01.000Z
# 34948           10  2018-05-10T17:00:01.000Z
# 34919           28  2018-05-13T18:51:13.000Z
# 34770           28  2018-05-13T18:51:13.000Z
# 34913           24  2018-05-13T16:42:33.000Z
# 34764           24  2018-05-13T16:42:33.000Z
#
#                                                     tags    views  likes  \
# 34906  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786  19880
# 34757  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786  19880
# 34917  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387   1488
# 34768  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387   1488
# 34799  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...  1201548  51670
# 34948  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...  1201548  51670
# 34919  $1000 Survival Kit|"Survival Kit in a Case"|"p...  1289899  51318
# 34770  $1000 Survival Kit|"Survival Kit in a Case"|"p...  1289899  51318
# 34913  box fort|"fort"|"kids"|"funny"|"fun"|"no swear...  1030616  20251
# 34764  box fort|"fort"|"kids"|"funny"|"fun"|"no swear...  1030616  20251
#
#        dislikes  comment_count  \
# 34906       248            669
# 34757       248            669
# 34917       251           1087
# 34768       251           1087
# 34799       964           4264
# 34948       964           4264
# 34919      1359           4332
# 34770      1359           4332
# 34913      3290           3567
# 34764      3290           3567
#
#                                        thumbnail_link  comments_disabled  \
# 34906  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34757  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34917  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34768  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34799  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg              False
# 34948  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg              False
# 34919  https://i.ytimg.com/vi/3g5O-kT9m8k/default.jpg              False
# 34770  https://i.ytimg.com/vi/3g5O-kT9m8k/default.jpg              False
# 34913  https://i.ytimg.com/vi/4oqvNR1o3Zo/default.jpg              False
# 34764  https://i.ytimg.com/vi/4oqvNR1o3Zo/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 34906             False                   False
# 34757             False                   False
# 34917             False                   False
# 34768             False                   False
# 34799             False                   False
# 34948             False                   False
# 34919             False                   False
# 34770             False                   False
# 34913             False                   False
# 34764             False                   False
#
#                                              description
# 34906  Sarah Paulson agreed to play a friendly game o...
# 34757  Sarah Paulson agreed to play a friendly game o...
# 34917  Three new fissures have opened on Hawaii's Big...
# 34768  Three new fissures have opened on Hawaii's Big...
# 34799  Spotify: http://radi.al/NewLightSpotifyApple: ...
# 34948  Spotify: http://radi.al/NewLightSpotifyApple: ...
# 34919  $15 Survival Kit Unboxing - https://youtu.be/0...
# 34770  $15 Survival Kit Unboxing - https://youtu.be/0...
# 34913  In Todays 24 hour Box Fort video papa Jake bui...
# 34764  In Todays 24 hour Box Fort video papa Jake bui...

# %% [markdown]
# ## Remove Duplicates
# Use `drop_duplicates()` to remove duplicate rows.
# - `df.shape` returns a amount of the rows and columns of the DataFrame as a tuple.

# %%
# Use deep copy, so it won't affect the original DataFrame.
q1_video_df = INITIAL_VIDEO_DF.copy()

# Rows and columns of the original DataFrame.
print(f"Original DataFrame shape: {q1_video_df.shape}")
print(f"- {q1_video_df.shape[0]} rows")
print(f"- {q1_video_df.shape[1]} columns")
# Out:
# Original DataFrame shape: (40949, 16)
# - 40949 rows
# - 16 columns

# %%
# Remove duplicate rows.
q1_video_df = q1_video_df.drop_duplicates()

# Rows and columns of the modified DataFrame.
print(f"Modified DataFrame shape: {q1_video_df.shape}")
print(f"- {q1_video_df.shape[0]} rows")
print(f"- {q1_video_df.shape[1]} columns")
# Out:
# Modified DataFrame shape: (40901, 16)
# - 40901 rows
# - 16 columns

# %% [markdown]
# # Function `Q2`
# How many VDO that have "dislikes" more than "likes"? Make sure that you count only unique title!
#
# **Assume that**
# - `videos.csv` has been loaded into memory and is ready to be utilized as `vdo_df`
# - The duplicate rows of `vdo_df` have been removed.

# %% [markdown]
# ## Column Access
# - Access the title column by using `vdo_df["dislikes"]`
# - Access the dislike count column by using `vdo_df["dislikes"]`
# - Access the like count column by using `vdo_df["likes"]`
# - Access those 3 columns at the same time by using the command below.
#
# **NOTE:** `head(10)` is a command to show only the top 10 rows.

# %%
VIDEO_DF[["title", "dislikes", "likes"]].head(10)
# Out:
#                                                title  dislikes   likes
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE      2966   57527
# 1  The Trump Presidency: Last Week Tonight with J...      6146   97185
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...      5339  146033
# 3                   Nickelback Lyrics: Real or Fake?       666   10172
# 4                           I Dare You: GOING BALD!?      1989  132235
# 5                              2 Weeks with iPhone X       511    9763
# 6          Roy Moore & Jeff Sessions Cold Open - SNL      2445   15993
# 7                5 Ice Cream Gadgets put to the Test       778   23663
# 8  The Greatest Showman | Official Trailer 2 [HD]...       119    3543
# 9  Why the rise of the robots won’t mean the end ...      1363   12654

# %% [markdown]
# ## Rows Filtering
# - Video dislike count is `VIDEO_DF["dislikes"]`
# - Video like count is `VIDEO_DF["likes"]`
# - Filter a video with dislikes count more than likes count by using the condition `VIDEO_DF["dislikes"] > VIDEO_DF["likes"]`

# %%
# Use deep copy, so it won't affect the original DataFrame.
q2_video_df = VIDEO_DF.copy()

# Filter conditions
Q2_FILTER_CONDITIONS = q2_video_df["dislikes"] > q2_video_df["likes"]

# %% [markdown]
# Display example rows of the filtered DataFrame.

# %%
q2_video_df = q2_video_df[Q2_FILTER_CONDITIONS]
q2_video_df.head(10)
# Out:
#         video_id trending_date  \
# 43   0tO_l_Ed5Rs      17.14.11
# 47   sbcbvuitiTc      17.14.11
# 75   k8NxqyGcZA4      17.14.11
# 133  X7flefV8tec      17.14.11
# 169  bhoFXkVy8JA      17.14.11
# 195  u7pV4vxD1bs      17.14.11
# 295  VJlSq6h0LNg      17.15.11
# 305  0tO_l_Ed5Rs      17.15.11
# 307  1WDj0DddCcM      17.15.11
# 312  sbcbvuitiTc      17.15.11
#
#                                                  title  \
# 43   Matthew Santoro - FACTS (Official Music Video)...
# 47   Stephon Marbury and Jimmer Fredette fight in C...
# 75   Rosie O’Donnell On Donald Trump’s Hostility To...
# 133  President Bill Clinton On Dictators, Democracy...
# 169                            Basmati Blues - Trailer
# 195  World's first self-driving shuttle crashes on ...
# 295         HOL HD: Mike Riley Monday Press Conference
# 305  Matthew Santoro - FACTS (Official Music Video)...
# 307          WATCH: Sen. Mitch McConnell on tax reform
# 312  Stephon Marbury and Jimmer Fredette fight in C...
#
#                                channel_title  category_id  \
# 43                            MatthewSantoro           10
# 47                  NBA Highlights · YouTube           17
# 75   Watch What Happens Live with Andy Cohen           24
# 133                                Team Coco           24
# 169                              Blockbuster            1
# 195                    KSNV News 3 Las Vegas           25
# 295                           Gregg Peterson           17
# 305                           MatthewSantoro           10
# 307                     WLKY News Louisville           25
# 312                 NBA Highlights · YouTube           17
#
#                  publish_time  \
# 43   2017-11-11T16:00:01.000Z
# 47   2017-11-10T18:23:05.000Z
# 75   2017-11-10T12:59:55.000Z
# 133  2017-11-09T02:37:49.000Z
# 169  2017-10-13T08:20:03.000Z
# 195  2017-11-08T20:16:47.000Z
# 295  2017-11-13T18:41:18.000Z
# 305  2017-11-11T16:00:01.000Z
# 307  2017-11-13T16:14:00.000Z
# 312  2017-11-10T18:23:05.000Z
#
#                                                   tags    views  likes  \
# 43   matthew santoro facts|"music video"|"matthew s...   328330  15186
# 47                           NBA|"Basketball"|"Sports"   956169   2017
# 75   What What Happens live|"reality"|"interview"|"...   238643   2429
# 133                                             [none]   366180   4364
# 169  Blockbuster|"blockbuster.dk"|"blockbuster.se"|...    12609     40
# 195   Technology|"self-driving car"|"Las Vegas"|"News"   169511     57
# 295  HuskerOnline.com|"Nebraska Football"|"Huskers"...     6684     18
# 305  matthew santoro facts|"music video"|"matthew s...   360223  15873
# 307                                             [none]     6685     11
# 312                          NBA|"Basketball"|"Sports"  1015189   2133
#
#      dislikes  comment_count                                  thumbnail_link  \
# 43      15448           7484  https://i.ytimg.com/vi/0tO_l_Ed5Rs/default.jpg
# 47       2425           1447  https://i.ytimg.com/vi/sbcbvuitiTc/default.jpg
# 75       5381           2325  https://i.ytimg.com/vi/k8NxqyGcZA4/default.jpg
# 133      4448           1997  https://i.ytimg.com/vi/X7flefV8tec/default.jpg
# 169        79             17  https://i.ytimg.com/vi/bhoFXkVy8JA/default.jpg
# 195        59             79  https://i.ytimg.com/vi/u7pV4vxD1bs/default.jpg
# 295        57             54  https://i.ytimg.com/vi/VJlSq6h0LNg/default.jpg
# 305     16033           7803  https://i.ytimg.com/vi/0tO_l_Ed5Rs/default.jpg
# 307        35             18  https://i.ytimg.com/vi/1WDj0DddCcM/default.jpg
# 312      2483           1465  https://i.ytimg.com/vi/sbcbvuitiTc/default.jpg
#
#      comments_disabled  ratings_disabled  video_error_or_removed  \
# 43               False             False                   False
# 47               False             False                   False
# 75               False             False                   False
# 133              False             False                   False
# 169              False             False                   False
# 195              False             False                   False
# 295              False             False                   False
# 305              False             False                   False
# 307              False             False                   False
# 312              False             False                   False
#
#                                            description
# 43   LISTEN WITH HEADPHONES! 🎧. WATCH IN 4K! 👀\nPro...
# 47                                                 NaN
# 75   Rosie O’Donnell doesn’t hold back about Donald...
# 133  #ConanNYC Highlight: President Clinton talks a...
# 169                            Basmati Blues - Trailer
# 195  Las Vegas is the first city in America to have...
# 295  Nebraska Head Coach Mike Riley with the media ...
# 305  LISTEN WITH HEADPHONES! 🎧. WATCH IN 4K! 👀\nPro...
# 307  Senate Majority Leader Mitch McConnell talks a...
# 312                                                NaN

# %% [markdown]
# ## Unique Video Titles
# Despite removing duplicate rows before processing, some rows might have duplicate video titles. For example.

# %%
q2_video_df[q2_video_df.duplicated(subset=["title"], keep=False)].sort_values(
    by="video_id"
).head(10)
# Out:
#           video_id trending_date  \
# 35083  0IaG9oM4O4s      18.16.05
# 36120  0IaG9oM4O4s      18.21.05
# 35903  0IaG9oM4O4s      18.20.05
# 35700  0IaG9oM4O4s      18.19.05
# 35499  0IaG9oM4O4s      18.18.05
# 33799  0IaG9oM4O4s      18.10.05
# 34011  0IaG9oM4O4s      18.11.05
# 35290  0IaG9oM4O4s      18.17.05
# 34565  0IaG9oM4O4s      18.14.05
# 34449  0IaG9oM4O4s      18.13.05
#
#                                                    title channel_title  \
# 35083  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 36120  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 35903  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 35700  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 35499  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 33799  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 34011  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 35290  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 34565  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
# 34449  Speechless Thoughts with Charles Barkley - Clo...    McDonald's
#
#        category_id              publish_time      tags    views  likes  \
# 35083            1  2018-05-06T03:02:12.000Z  yt:cc=on  1673475   6874
# 36120            1  2018-05-06T03:02:12.000Z  yt:cc=on  1675909   6873
# 35903            1  2018-05-06T03:02:12.000Z  yt:cc=on  1675496   6874
# 35700            1  2018-05-06T03:02:12.000Z  yt:cc=on  1675041   6876
# 35499            1  2018-05-06T03:02:12.000Z  yt:cc=on  1674678   6876
# 33799            1  2018-05-06T03:02:12.000Z  yt:cc=on  1654618   6790
# 34011            1  2018-05-06T03:02:12.000Z  yt:cc=on  1658336   6801
# 35290            1  2018-05-06T03:02:12.000Z  yt:cc=on  1674171   6876
# 34565            1  2018-05-06T03:02:12.000Z  yt:cc=on  1664324   6854
# 34449            1  2018-05-06T03:02:12.000Z  yt:cc=on  1661389   6794
#
#        dislikes  comment_count  \
# 35083      7018              0
# 36120      7029              0
# 35903      7027              0
# 35700      7026              0
# 35499      7024              0
# 33799      6850              0
# 34011      6880              0
# 35290      7021              0
# 34565      6984              0
# 34449      6882              0
#
#                                        thumbnail_link  comments_disabled  \
# 35083  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 36120  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 35903  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 35700  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 35499  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 33799  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 34011  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 35290  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 34565  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
# 34449  https://i.ytimg.com/vi/0IaG9oM4O4s/default.jpg               True
#
#        ratings_disabled  video_error_or_removed  \
# 35083             False                   False
# 36120             False                   False
# 35903             False                   False
# 35700             False                   False
# 35499             False                   False
# 33799             False                   False
# 34011             False                   False
# 35290             False                   False
# 34565             False                   False
# 34449             False                   False
#
#                                              description
# 35083  Introducing McDonald’s new 100% fresh beef Qua...
# 36120  Introducing McDonald’s new 100% fresh beef Qua...
# 35903  Introducing McDonald’s new 100% fresh beef Qua...
# 35700  Introducing McDonald’s new 100% fresh beef Qua...
# 35499  Introducing McDonald’s new 100% fresh beef Qua...
# 33799  Introducing McDonald’s new 100% fresh beef Qua...
# 34011  Introducing McDonald’s new 100% fresh beef Qua...
# 35290  Introducing McDonald’s new 100% fresh beef Qua...
# 34565  Introducing McDonald’s new 100% fresh beef Qua...
# 34449  Introducing McDonald’s new 100% fresh beef Qua...

# %% [markdown]
# Use `drop_duplicates()` to remove duplicate rows.
# - `subset` argument tells Pandas to consider duplicate on only the specified rows.

# %%
# Rows and columns of the original DataFrame.
print(f"Original DataFrame shape: {q2_video_df.shape}")
print(f"- {q2_video_df.shape[0]} rows")
print(f"- {q2_video_df.shape[1]} columns")
# Out:
# Original DataFrame shape: (576, 16)
# - 576 rows
# - 16 columns

# %%
# Remove rows with duplicate video title.
q2_video_df = q2_video_df.drop_duplicates(subset=["title"])

# Rows and columns of the modified DataFrame.
print(f"Modified DataFrame shape: {q2_video_df.shape}")
print(f"- {q2_video_df.shape[0]} rows")
print(f"- {q2_video_df.shape[1]} columns")
# Out:
# Modified DataFrame shape: (122, 16)
# - 122 rows
# - 16 columns

# %% [markdown]
# # Function `Q3`
# How many VDO that are trending on 22 Jan 2018 with comments more than 10,000 comments?
# - The trending date of `vdo_df` is represented as `YY.DD.MM`. For example, `January 22, 2018`, is represented as `18.22.01`.
#
# **Assume that**
# - `videos.csv` has been loaded into memory and is ready to be utilized as `vdo_df`
# - The duplicate rows of `vdo_df` have been removed.

# %% [markdown]
# ## Rows Filtering
# - Video trending date is `VIDEO_DF["trending_date"]`
# - Video comment count is `VIDEO_DF["comment_count"]`
# - Filter a video with trending date on January 22, 2018 by using the condition `VIDEO_DF["trending_date"] == "18.22.01"`
# - Filter a video with comment count more than 10000 by using the condition `VIDEO_DF["comment_count"] > 10000`
# - AND operation on Pandas filtering is `&`

# %%
# Use deep copy, so it won't affect the original DataFrame.
q3_video_df = VIDEO_DF.copy()

# Filter conditions
Q3_FILTER_CONDITIONS = (q3_video_df["trending_date"] == "18.22.01") & (
    q3_video_df["comment_count"] > 10000
)

# %% [markdown]
# Display example rows of the filtered DataFrame.

# %%
q3_video_df = q3_video_df[Q3_FILTER_CONDITIONS]
q3_video_df.head(10)
# Out:
#           video_id trending_date  \
# 13400  aYnyMPc3LQ4      18.22.01
# 13402  WAwRrtH-4Lg      18.22.01
# 13403  Y-iFgDK_D5s      18.22.01
# 13404  Isvqg90LhqM      18.22.01
# 13415  aB-UKwO367s      18.22.01
# 13417  lrWRy9BBp-c      18.22.01
# 13419  MLVcmQ62luE      18.22.01
# 13421  lUZPV3gGXgY      18.22.01
# 13429  _7985zBEM3o      18.22.01
# 13432  CJzaYLc4pPY      18.22.01
#
#                                                    title  \
# 13400                  How to Make Life More Interesting
# 13402                                 My Horibal Speling
# 13403               The Smallest Bird you have ever seen
# 13404                        Lucas the Spider - Captured
# 13415  Film Theory: How Star Wars Theories KILLED Sta...
# 13417             ELDERS REACT TO UGANDAN KNUCKLES MEMES
# 13419  I Tried Cutting My Hair Off With A Sword Like ...
# 13421  Magic Transforming Top Coat?! (does this thing...
# 13429                  Primitive Technology: A-frame hut
# 13432                                       NF - NO NAME
#
#                channel_title  category_id              publish_time  \
# 13400      Jaiden Animations            1  2018-01-21T18:15:56.000Z
# 13402            TheOdd1sOut           23  2018-01-20T17:15:48.000Z
# 13403  A Chick Called Albert           15  2018-01-21T00:10:07.000Z
# 13404       Lucas the Spider            1  2018-01-20T07:30:09.000Z
# 13415     The Film Theorists            1  2018-01-19T19:05:50.000Z
# 13417                    FBE           24  2018-01-19T22:00:02.000Z
# 13419                 Boldly           22  2018-01-19T19:00:38.000Z
# 13421      Simply Nailogical           24  2018-01-20T15:57:00.000Z
# 13429   Primitive Technology           22  2018-01-19T21:09:10.000Z
# 13432                 NFVEVO           10  2018-01-19T05:00:00.000Z
#
#                                                     tags    views   likes  \
# 13400  jaiden|"animations"|"jaidenanimation"|"jaidena...  1864342  159415
# 13402  spelling|"school"|"teacher"|"speech"|"audioboo...  5686453  334806
# 13403  wren|"baby bird"|"incubating"|"nest"|"birdnest...  1481728   64756
# 13404  Lucas the Spider|"VFX"|"Animation"|"3D Animati...  2718728  148313
# 13415  star wars|"last jedi"|"the last jedi"|"star wa...  3309330  119622
# 13417  ugandan knuckles memes|"ugandan knuckles"|"uga...  1874710   54224
# 13419  BuzzFeed|"BuzzFeedBoldly"|"BuzzFeed Boldly"|"B...  6534482  169810
# 13421  nails|"nail art"|"nail tutorial"|"beauty tutor...  1923322  113141
# 13429                                             [none]  3702942  161760
# 13432  NF official|"nfrealmusic"|"Nate"|"i leave it a...  2176746  152192
#
#        dislikes  comment_count  \
# 13400      1643          61862
# 13402      3787          70565
# 13403      1015          10121
# 13404      2490          12075
# 13415     11219          36833
# 13417      4897          14099
# 13419     15475          12686
# 13421       839          12799
# 13429      1414          13839
# 13432      2789          20811
#
#                                        thumbnail_link  comments_disabled  \
# 13400  https://i.ytimg.com/vi/aYnyMPc3LQ4/default.jpg              False
# 13402  https://i.ytimg.com/vi/WAwRrtH-4Lg/default.jpg              False
# 13403  https://i.ytimg.com/vi/Y-iFgDK_D5s/default.jpg              False
# 13404  https://i.ytimg.com/vi/Isvqg90LhqM/default.jpg              False
# 13415  https://i.ytimg.com/vi/aB-UKwO367s/default.jpg              False
# 13417  https://i.ytimg.com/vi/lrWRy9BBp-c/default.jpg              False
# 13419  https://i.ytimg.com/vi/MLVcmQ62luE/default.jpg              False
# 13421  https://i.ytimg.com/vi/lUZPV3gGXgY/default.jpg              False
# 13429  https://i.ytimg.com/vi/_7985zBEM3o/default.jpg              False
# 13432  https://i.ytimg.com/vi/CJzaYLc4pPY/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 13400             False                   False
# 13402             False                   False
# 13403             False                   False
# 13404             False                   False
# 13415             False                   False
# 13417             False                   False
# 13419             False                   False
# 13421             False                   False
# 13429             False                   False
# 13432             False                   False
#
#                                              description
# 13400  it includes apples\n\nOther Animation Buds!\nP...
# 13402  hOI guis!!1! Thx 4 wathcing my vid abuot my ho...
# 13403  By accident I got hold of two of the smallest ...
# 13404  Lucas may or may not know that he is in danger...
# 13415  SUBSCRIBE for More Film Theories! ► http://bit...
# 13417  Ugandan Knuckles Memes reacted to by Elders! O...
# 13419  This is 90 to 100 percent dangerous. Do not tr...
# 13421  Prepare yourself for this is an actual nail vi...
# 13429  I built an A frame hut as a large work space f...
# 13432  Official music video for “NO NAME” by NF.\nGet...

# %% [markdown]
# Count number of rows of the filtered DataFrame.

# %%
# Rows and columns of the modified DataFrame.
print(f"Filtered DataFrame shape: {q3_video_df.shape}")
print(f"- {q3_video_df.shape[0]} rows")
print(f"- {q3_video_df.shape[1]} columns")
# Out:
# Filtered DataFrame shape: (28, 16)
# - 28 rows
# - 16 columns

# %% [markdown]
# # Function `Q4`
# Which trending date that has the minimum average number of comments per VDO?
#
# **Assume that**
# - `videos.csv` has been loaded into memory and is ready to be utilized as `vdo_df`
# - The duplicate rows of `vdo_df` have been removed.

# %% [markdown]
# ## Row Grouping
# We need to calculate average of `comment_count` grouped by `trending_date`.
# - Use `.groupby("trending_date")` to group rows with the same `trending_date`.
# - Use `["comment_count"].mean()` to get average value of `comment_count` on the same trending date.
# - Use `.reset_index(name="avg_comment_count")` to rename the column into `avg_comment_count`

# %%
# Use deep copy, so it won't affect the original DataFrame.
q4_video_df = VIDEO_DF.copy()

# Row grouping
q4_video_df = (
    q4_video_df.groupby("trending_date")["comment_count"]
    .mean()
    .reset_index(name="avg_comment_count")
)

# %% [markdown]
# Display example rows of the grouped DataFrame.

# %%
q4_video_df.head(10)
# Out:
#   trending_date  avg_comment_count
# 0      17.01.12           7814.060
# 1      17.02.12           5114.815
# 2      17.03.12           5223.455
# 3      17.04.12           5168.260
# 4      17.05.12           5406.045
# 5      17.06.12           5877.095
# 6      17.07.12           8385.340
# 7      17.08.12           9167.755
# 8      17.09.12           9072.340
# 9      17.10.12           8412.595

# %% [markdown]
# ## Minimum Value
# Use `.min()` to get minimum value.

# %%
print(f"Minimum average comment count {q4_video_df["avg_comment_count"].min()}")
# Out:
# Minimum average comment count 1965.3869346733668

# %% [markdown]
# Filter rows with minimum average comment count.

# %%
Q4_FILTER_CONDITIONS = (
    q4_video_df["avg_comment_count"] == q4_video_df["avg_comment_count"].min()
)

q4_video_df[Q4_FILTER_CONDITIONS]
# Out:
#    trending_date  avg_comment_count
# 73      18.05.02        1965.386935

# %% [markdown]
# `.iloc[]` command is to select a data from DataFrame from specific row and column indices.

# %%
# Get the first date of "trending_date" column from filtered DataFrame.
date = q4_video_df[Q4_FILTER_CONDITIONS]["trending_date"].iloc[0]

print(f"The trending date with lowest average comment count is {date}")
# Out:
# The trending date with lowest average comment count is 18.05.02

# %% [markdown]
# # Function `Q5`
# Compare `Sports` and `Comedy`, how many days that there are more total daily views of VDO in `Sports` category than in `Comedy` category?
# - You must load the additional data from `category_id.json` into memory before executing any operations.
# - To access `category_id.json`, use the path `/data/category_id.json`.
#
# **Assume that**
# - `videos.csv` has been loaded into memory and is ready to be utilized as `vdo_df`
# - The duplicate rows of `vdo_df` have been removed.

# %% [markdown]
# ## Access JSON DataFrame
# Display categories DataFrame

# %%
CATEGORIES_DF
# Out:
#                                  kind  \
# 0   youtube#videoCategoryListResponse
# 1   youtube#videoCategoryListResponse
# 2   youtube#videoCategoryListResponse
# 3   youtube#videoCategoryListResponse
# 4   youtube#videoCategoryListResponse
# 5   youtube#videoCategoryListResponse
# 6   youtube#videoCategoryListResponse
# 7   youtube#videoCategoryListResponse
# 8   youtube#videoCategoryListResponse
# 9   youtube#videoCategoryListResponse
# 10  youtube#videoCategoryListResponse
# 11  youtube#videoCategoryListResponse
# 12  youtube#videoCategoryListResponse
# 13  youtube#videoCategoryListResponse
# 14  youtube#videoCategoryListResponse
# 15  youtube#videoCategoryListResponse
# 16  youtube#videoCategoryListResponse
# 17  youtube#videoCategoryListResponse
# 18  youtube#videoCategoryListResponse
# 19  youtube#videoCategoryListResponse
# 20  youtube#videoCategoryListResponse
# 21  youtube#videoCategoryListResponse
# 22  youtube#videoCategoryListResponse
# 23  youtube#videoCategoryListResponse
# 24  youtube#videoCategoryListResponse
# 25  youtube#videoCategoryListResponse
# 26  youtube#videoCategoryListResponse
# 27  youtube#videoCategoryListResponse
# 28  youtube#videoCategoryListResponse
# 29  youtube#videoCategoryListResponse
# 30  youtube#videoCategoryListResponse
# 31  youtube#videoCategoryListResponse
#
#                                                  etag  \
# 0   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 5   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 6   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 7   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 8   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 9   "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 10  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 11  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 12  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 13  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 14  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 15  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 16  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 17  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 18  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 19  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 20  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 21  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 22  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 23  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 24  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 25  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 26  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 27  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 28  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 29  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 30  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 31  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                 items
# 0   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 5   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 6   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 7   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 8   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 9   {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 10  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 11  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 12  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 13  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 14  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 15  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 16  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 17  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 18  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 19  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 20  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 21  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 22  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 23  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 24  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 25  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 26  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 27  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 28  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 29  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 30  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 31  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %% [markdown]
# See example data on `items` column

# %%
# Get the first data from the items column
example_data = CATEGORIES_DF["items"].iloc[0]

# Output the example data with its data type.
print("Example data on 'items' column")
print(example_data)
print(f"\nData type: {type(example_data)}")
# Out:
# Example data on 'items' column
# {'kind': 'youtube#videoCategory', 'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKmPBggty2mZQ"', 'id': '1', 'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ', 'title': 'Film & Animation', 'assignable': True}}
#
# Data type: <class 'dict'>

# %% [markdown]
# - As we can see, all data on `items` column are `dict`.
# - We can access `id` and `title` of each category using the command below.

# %%
# Get the first data from the items column
example_data = CATEGORIES_DF["items"].iloc[0]

# Get category ID and name.
print(f"Category ID: {example_data["id"]}")
print(f"Category name: {example_data["snippet"]["title"]}")
# Out:
# Category ID: 1
# Category name: Film & Animation

# %% [markdown]
# ## Mapping Values
# - In the CSV file, it has only category ID for each video, but no category name.
# - In the JSON file, it has both category ID with the category name.

# %%
# Show the first 10 rows with video title and category ID.
VIDEO_DF[["title", "category_id"]].head(10)
# Out:
#                                                title  category_id
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           22
# 1  The Trump Presidency: Last Week Tonight with J...           24
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           23
# 3                   Nickelback Lyrics: Real or Fake?           24
# 4                           I Dare You: GOING BALD!?           24
# 5                              2 Weeks with iPhone X           28
# 6          Roy Moore & Jeff Sessions Cold Open - SNL           24
# 7                5 Ice Cream Gadgets put to the Test           28
# 8  The Greatest Showman | Official Trailer 2 [HD]...            1
# 9  Why the rise of the robots won’t mean the end ...           25

# %% [markdown]
# - To process the data further, we need to create `category_name` column from `category_id` value.
# - So we need a `dict` to map `category_id` to `category_name`.

# %%
# Initialize a dict to store mappings.
CATEGORIES_MAPPINGS = {}

# Iterate each value in items column from JSON file DataFrame.
for data in CATEGORIES_DF["items"]:
    # Extract the category ID and name from raw value.
    category_id = int(data["id"])
    category_name = data["snippet"]["title"]

    # Store the mappings to a dict.
    CATEGORIES_MAPPINGS[category_id] = category_name

# Display mappings dict
print("========== CATEGORIES MAPPINGS ==========")
for category_id, category_name in CATEGORIES_MAPPINGS.items():
    print(f"{category_id} --> {category_name}")
# Out:
# ========== CATEGORIES MAPPINGS ==========
# 1 --> Film & Animation
# 2 --> Autos & Vehicles
# 10 --> Music
# 15 --> Pets & Animals
# 17 --> Sports
# 18 --> Short Movies
# 19 --> Travel & Events
# 20 --> Gaming
# 21 --> Videoblogging
# 22 --> People & Blogs
# 23 --> Comedy
# 24 --> Entertainment
# 25 --> News & Politics
# 26 --> Howto & Style
# 27 --> Education
# 28 --> Science & Technology
# 29 --> Nonprofits & Activism
# 30 --> Movies
# 31 --> Anime/Animation
# 32 --> Action/Adventure
# 33 --> Classics
# 34 --> Comedy
# 35 --> Documentary
# 36 --> Drama
# 37 --> Family
# 38 --> Foreign
# 39 --> Horror
# 40 --> Sci-Fi/Fantasy
# 41 --> Thriller
# 42 --> Shorts
# 43 --> Shows
# 44 --> Trailers

# %% [markdown]
# Create `category_name` column from `category_id` value by mapping values using `.map()`.

# %%
# Use deep copy, so it won't affect the original DataFrame.
q5_video_df = VIDEO_DF.copy()

# Create the category_name column by mapping values.
q5_video_df["category_name"] = q5_video_df["category_id"].map(CATEGORIES_MAPPINGS)

# %% [markdown]
# Show the example rows with video title, category ID, and category name.

# %%
q5_video_df[["title", "category_id", "category_name"]].head(10)
# Out:
#                                                title  category_id  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           22
# 1  The Trump Presidency: Last Week Tonight with J...           24
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           23
# 3                   Nickelback Lyrics: Real or Fake?           24
# 4                           I Dare You: GOING BALD!?           24
# 5                              2 Weeks with iPhone X           28
# 6          Roy Moore & Jeff Sessions Cold Open - SNL           24
# 7                5 Ice Cream Gadgets put to the Test           28
# 8  The Greatest Showman | Official Trailer 2 [HD]...            1
# 9  Why the rise of the robots won’t mean the end ...           25
#
#           category_name
# 0        People & Blogs
# 1         Entertainment
# 2                Comedy
# 3         Entertainment
# 4         Entertainment
# 5  Science & Technology
# 6         Entertainment
# 7  Science & Technology
# 8      Film & Animation
# 9       News & Politics

# %% [markdown]
# ## Rows Filtering 1
# - Filter videos with only `Sports` or `Comedy` category.
# - Use `.isin()` instead of traditional `in`.

# %%
Q5_FILTER_CONDITIONS = q5_video_df["category_name"].isin(["Sports", "Comedy"])

q5_video_df = q5_video_df[Q5_FILTER_CONDITIONS]

q5_video_df[["trending_date", "title", "category_name", "views"]].head(10)
# Out:
#    trending_date                                              title  \
# 2       17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 10      17.14.11  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# 16      17.14.11   One Change That Would Make Pacific Rim a Classic
# 24      17.14.11                       Using Other People's Showers
# 38      17.14.11                  Celebrities on Thanksgiving 2017!
# 42      17.14.11  Dennis Smith Jr. and LeBron James go back and ...
# 47      17.14.11  Stephon Marbury and Jimmer Fredette fight in C...
# 48      17.14.11  Heidelberg's nifty hook-and-lateral to the lef...
# 52      17.14.11  Wildest Superstar distractions: WWE Top 10, No...
# 56      17.14.11   JaVale McGee's Parking Lot Chronicles: Episode 3
#
#    category_name    views
# 2         Comedy  3191434
# 10        Sports    81377
# 16        Comedy   295639
# 24        Comedy    33980
# 38        Comedy   605932
# 42        Sports      945
# 47        Sports   956169
# 48        Sports     4569
# 52        Sports  1044813
# 56        Sports   162597

# %% [markdown]
# ## Pivot Table
# Pivot table is a tool to group, analyze, and summarize data which is suitable to a complex grouping task like this problem.
# - `index` is the rows value which is `trending_date`.
# - `columns` is the columns header value which is `category_name` (`Sports` and `Comedy`).
# - `values` is the calculated number which is `views`.
# - `aggfunc` is the math function to calculate which is `sum` because we need total daily view.

# %%
q5_pivot_table = q5_video_df.pivot_table(
    index=["trending_date"], columns=["category_name"], values=["views"], aggfunc="sum"
)

# %% [markdown]
# Display pivot table.
#
# Now, we can see total daily view of each category.

# %%
q5_pivot_table
# Out:
#                   views
# category_name    Comedy    Sports
# trending_date
# 17.01.12       29459704   4947643
# 17.02.12       24083012   4802877
# 17.03.12       16837274   5093234
# 17.04.12       20043612   2812344
# 17.05.12       18387739   2576643
# ...                 ...       ...
# 18.30.04       26772261  31745208
# 18.30.05       36164679  36885940
# 18.31.01       16354380  13811205
# 18.31.03       34406584  39866555
# 18.31.05       39433419  23835174
#
# [205 rows x 2 columns]

# %% [markdown]
# ## Rows Filtering 2
# - Comedy video total daily views is `q5_pivot_table[("views", "Comedy")]`
# - Sports video total daily views is `q5_pivot_table[("views", "Sports")]`
# - Filter trending days with sports video is more than comedy video total daily views by using the command below.

# %%
Q5_FILTER_CONDITIONS = (
    q5_pivot_table[("views", "Sports")] > q5_pivot_table[("views", "Comedy")]
)

q5_pivot_table = q5_pivot_table[Q5_FILTER_CONDITIONS]

q5_pivot_table.head(10)
# Out:
#                   views
# category_name    Comedy    Sports
# trending_date
# 17.08.12       11446860  15371509
# 17.09.12       13370111  16486158
# 17.10.12        9673327  17393221
# 17.11.12       13546532  18182222
# 17.12.12       16862089  17136185
# 18.01.02       15977689  18489773
# 18.01.03       15594887  33125456
# 18.01.04       33581982  43225051
# 18.01.05       28012076  32935402
# 18.02.02       16988313  22040288

# %%
# Rows and columns of the modified DataFrame.
print(f"Filtered pivot table shape: {q5_pivot_table.shape}")
print(f"- {q5_pivot_table.shape[0]} rows")
print(f"- {q5_pivot_table.shape[1]} columns")
# Out:
# Filtered pivot table shape: (83, 2)
# - 83 rows
# - 2 columns
